# %%
import requests
from bs4 import BeautifulSoup as bs
from IPython.core.display import HTML
import pandas as pd

URL = 'https://ryman.com/events/'
response = requests.get(URL)

soup = bs(response.text)

# %% [markdown]
# List of artists, page 1 - 5.

# %%
page = 1
artistsmulti = []
while page != 6:
      url = f"https://ryman.com/events/list/?tribe_event_display=list&tribe_paged={page}"
      response = requests.get(url)
      html = response.content
      soup = bs(html, "lxml")
      for h3 in soup.find_all('a', attrs={'class': 'tribe-event-url'}):
            artistsmulti.append(h3.get_text(strip=True))
      page = page + 1
artistsmulti
# Out:
# ['Mt. Joy',
#  'Mt. Joy',
#  'Ryman Sidewalk Sessions',
#  'Marcus Mumford',
#  'Puscifer',
#  'Gipsy Kings featuring Nicolas Reyes',
#  'Ryman Sidewalk Sessions',
#  'Cole Swindell',
#  'Ryman Sidewalk Sessions',
#  'Cole Swindell',
#  'The Lone Bellow',
#  'We The Kingdom',
#  'The Revivalists',
#  'The Revivalists',
#  'Dayglow',
#  'Bono: Stories of Surrender',
#  'Chris Renzema',
#  'Craig Morgan',
#  'Louder with Crowder',
#  'Louder with Crowder',
#  'Disney Junior Live On Tour',
#  'Lynyrd Skynyrd',
#  'Charley Crockett',
#  'Tauren Wells',
#  'Sometimes Y',
#  'Trombone Shorty & Orleans Avenue',
#  'Dropkick Murphys',
#  'No Small Endeavor',
#  'Opry NextStage Live In Concert',
#  'Christmas 4 Kids',
#  'Omar Apollo',
#  'W.A.S.P.',
#  'Brett Eldredge',
#  'Brett Eldredge',
#  'Brett Eldredge',
#  'Natalie Grant & Danny Gokey',
#  'A Day To Remember',
#  'The Piano Guys',
#  'Jason Bonham’s Led Zeppelin Evening',
#  'The Mavericks',
#  'The Mavericks',
#  'The Smile',
#  'Andrew Peterson',
#  'Andrew Peterson',
#  'Lauren Daigle',
#  'Lauren Daigle',
#  'Lauren Daigle',
#  'Allman Family Revival',
#  'LeAnn Rimes',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'Louis C.K.',
#  'Amy Grant & Vince Gill',
#  'Smokey Robinson',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'for King + Country',
#  'Amy Grant & Vince Gill',
#  'for King + Country',
#  'Aaron Lewis',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'Amy Grant & Vince Gill',
#  'Music City Chorus Christmas Celebration',
#  'Home Free Family Christmas',
#  'NUTCRACKER! Magic of Christmas Ballet',
#  'NUTCRACKER! Magic of Christmas Ballet',
#  'Old Crow Medicine Show',
#  'Old Crow Medicine Show',
#  'Celebrating the Life of Justin Townes Earle',
#  'Opry at the Ryman',
#  'Opry at the Ryman',
#  'Opry at the Ryman',
#  'Opry at the Ryman',
#  'Lake Street Dive',
#  'Lake Street Dive',
#  'Opry at the Ryman',
#  'Kenny Wayne Shepherd',
#  'Opry at the Ryman',
#  'Andrew Dice Clay',
#  'Alter Bridge',
#  'Noah Kahan',
#  'Mitchell Tenpenny',
#  'Mitchell Tenpenny',
#  'Tove Lo',
#  'Big Thief',
#  'Dancing With The Stars',
#  'Colony House',
#  'Death Cab for Cutie',
#  'Ashley McBryde presents Lindeville Live',
#  'Ashley McBryde presents Lindeville Live',
#  'Cory Wong',
#  'Kathleen Madigan',
#  'Tedeschi Trucks Band',
#  'Tedeschi Trucks Band',
#  'Tedeschi Trucks Band',
#  'Dawes']

# %% [markdown]
# Data and time for all shows, page 1 - 5.

# %%
page = 1
tdmulti = []
while page != 6:
      url = f"https://ryman.com/events/list/?tribe_event_display=list&tribe_paged={page}"
      response = requests.get(url)
      html = response.content
      soup = bs(html, "lxml")
      for h3 in soup.find_all('div', attrs={'class': 'tribe-event-schedule-details'}):
            tdmulti.append(h3.get_text())
      page = page + 1
tdmulti
# Out:
# ['\nFriday, October 28, 2022 at 8:00 PM CDT\n',
#  '\nSaturday, October 29, 2022 at 8:00 PM CDT\n',
#  '\nSunday, October 30, 2022 at 6:00 PM CDT\n',
#  '\nSunday, October 30, 2022 at 8:00 PM CDT\n',
#  '\nMonday, October 31, 2022 at 7:30 PM CDT\n',
#  '\nTuesday, November 1, 2022 at 7:30 PM CDT\n',
#  '\nWednesday, November 2, 2022 at 5:30 PM CDT\n',
#  '\nWednesday, November 2, 2022 at 7:30 PM CDT\n',
#  '\nThursday, November 3, 2022 at 5:30 PM CDT\n',
#  '\nThursday, November 3, 2022 at 7:30 PM CDT\n',
#  '\nFriday, November 4, 2022 at 8:00 PM CDT\n',
#  '\nSaturday, November 5, 2022 at 7:00 PM CDT\n',
#  '\nSunday, November 6, 2022 at 7:30 PM CST\n',
#  '\nMonday, November 7, 2022 at 7:30 PM CST\n',
#  '\nTuesday, November 8, 2022 at 7:30 PM CST\n',
#  '\nWednesday, November 9, 2022 at 8:00 PM CST\n',
#  '\nThursday, November 10, 2022 at 7:30 PM CST\n',
#  '\nFriday, November 11, 2022 at 8:00 PM CST\n',
#  '\nSaturday, November 12, 2022 at 7:00 PM CST\n',
#  '\nSaturday, November 12, 2022 at 9:30 PM CST\n',
#  '\nSunday, November 13, 2022 at 4:00 PM CST\n',
#  '\nSunday, November 13, 2022 at 7:30 PM CST\n',
#  '\nMonday, November 14, 2022 at 7:30 PM CST\n',
#  '\nTuesday, November 15, 2022 at 7:30 PM CST\n',
#  '\nThursday, November 17, 2022 at 7:30 PM CST\n',
#  '\nFriday, November 18, 2022 at 8:00 PM CST\n',
#  '\nSaturday, November 19, 2022 at 7:30 PM CST\n',
#  '\nSunday, November 20, 2022 at 7:30 PM CST\n',
#  '\nSunday, November 20, 2022 at 7:30 PM CST\n',
#  '\nMonday, November 21, 2022 at 7:00 PM CST\n',
#  '\nTuesday, November 22, 2022 at 7:30 PM CST\n',
#  '\nWednesday, November 23, 2022 at 7:30 PM CST\n',
#  '\nFriday, November 25, 2022 at 8:00 PM CST\n',
#  '\nSaturday, November 26, 2022 at 8:00 PM CST\n',
#  '\nSunday, November 27, 2022 at 8:00 PM CST\n',
#  '\nMonday, November 28, 2022 at 7:30 PM CST\n',
#  '\nTuesday, November 29, 2022 at 8:00 PM CST\n',
#  '\nWednesday, November 30, 2022 at 7:30 PM CST\n',
#  '\nWednesday, November 30, 2022 at 8:00 PM CST\n',
#  '\nThursday, December 1, 2022 at 8:00 PM CST\n',
#  '\nFriday, December 2, 2022 at 8:00 PM CST\n',
#  '\nSaturday, December 3, 2022 at 8:00 PM CST\n',
#  '\nSunday, December 4, 2022 at 7:00 PM CST\n',
#  '\nMonday, December 5, 2022 at 7:00 PM CST\n',
#  '\nTuesday, December 6, 2022 at 7:30 PM CST\n',
#  '\nWednesday, December 7, 2022 at 7:30 PM CST\n',
#  '\nThursday, December 8, 2022 at 7:30 PM CST\n',
#  '\nFriday, December 9, 2022 at 8:00 PM CST\n',
#  '\nSaturday, December 10, 2022 at 8:00 PM CST\n',
#  '\nMonday, December 12, 2022 at 7:30 PM CST\n',
#  '\nTuesday, December 13, 2022 at 7:30 PM CST\n',
#  '\nWednesday, December 14, 2022 at 7:30 PM CST\n',
#  '\nWednesday, December 14, 2022 at 7:30 PM CST\n',
#  '\nThursday, December 15, 2022 at 7:30 PM CST\n',
#  '\nFriday, December 16, 2022 at 8:00 PM CST\n',
#  '\nSaturday, December 17, 2022 at 3:00 PM CST\n',
#  '\nSaturday, December 17, 2022 at 7:30 PM CST\n',
#  '\nSunday, December 18, 2022 at 3:00 PM CST\n',
#  '\nSunday, December 18, 2022 at 7:00 PM CST\n',
#  '\nSunday, December 18, 2022 at 7:30 PM CST\n',
#  '\nMonday, December 19, 2022 at 7:00 PM CST\n',
#  '\nMonday, December 19, 2022 at 7:30 PM CST\n',
#  '\nTuesday, December 20, 2022 at 3:00 PM CST\n',
#  '\nTuesday, December 20, 2022 at 7:30 PM CST\n',
#  '\nWednesday, December 21, 2022 at 3:00 PM CST\n',
#  '\nWednesday, December 21, 2022 at 7:30 PM CST\n',
#  '\nThursday, December 22, 2022 at 7:00 PM CST\n',
#  '\nFriday, December 23, 2022 at 8:00 PM CST\n',
#  '\nSaturday, December 24, 2022 at 1:00 PM CST\n',
#  '\nSaturday, December 24, 2022 at 5:00 PM CST\n',
#  '\nFriday, December 30, 2022 at 8:00 PM CST\n',
#  '\nSaturday, December 31, 2022 at 9:00 PM CST\n',
#  '\nWednesday, January 4, 2023 at 7:30 PM CST\n',
#  '\nFriday, January 6, 2023 at 7:00 PM CST\n',
#  '\nSaturday, January 7, 2023 at 7:00 PM CST\n',
#  '\nFriday, January 13, 2023 at 7:00 PM CST\n',
#  '\nSaturday, January 14, 2023 at 7:00 PM CST\n',
#  '\nThursday, January 19, 2023 at 8:00 PM CST\n',
#  '\nFriday, January 20, 2023 at 8:00 PM CST\n',
#  '\nSaturday, January 21, 2023 at 7:00 PM CST\n',
#  '\nFriday, January 27, 2023 at 8:00 PM CST\n',
#  '\nSaturday, January 28, 2023 at 8:00 AM CST\n',
#  '\nSunday, January 29, 2023 at 7:30 PM CST\n',
#  '\nMonday, January 30, 2023 at 7:30 PM CST\n',
#  '\nThursday, February 2, 2023 at 7:30 PM CST\n',
#  '\nFriday, February 3, 2023 at 8:00 PM CST\n',
#  '\nSaturday, February 4, 2023 at 8:00 PM CST\n',
#  '\nMonday, February 6, 2023 at 7:30 PM CST\n',
#  '\nTuesday, February 7, 2023 at 7:30 PM CST\n',
#  '\nThursday, February 9, 2023 at 8:00 PM CST\n',
#  '\nSaturday, February 11, 2023 at 8:00 PM CST\n',
#  '\nTuesday, February 14, 2023 at 7:30 PM CST\n',
#  '\nWednesday, February 15, 2023 at 8:00 PM CST\n',
#  '\nThursday, February 16, 2023 at 8:00 PM CST\n',
#  '\nFriday, February 17, 2023 at 8:00 PM CST\n',
#  '\nSaturday, February 18, 2023 at 8:00 PM CST\n',
#  '\nThursday, February 23, 2023 at 8:00 PM CST\n',
#  '\nFriday, February 24, 2023 at 8:00 PM CST\n',
#  '\nSaturday, February 25, 2023 at 8:00 PM CST\n',
#  '\nSaturday, March 4, 2023 at 8:00 PM CST\n']

# %% [markdown]
# Clean and separate dates and times.

# %%
# Cleaned up dates
datemulti = [x.split(', ',1)[-1] for x in tdmulti]
datemulti = [x.split(' at ',1)[0] for x in datemulti]
datemulti
# Out:
# ['October 28, 2022',
#  'October 29, 2022',
#  'October 30, 2022',
#  'October 30, 2022',
#  'October 31, 2022',
#  'November 1, 2022',
#  'November 2, 2022',
#  'November 2, 2022',
#  'November 3, 2022',
#  'November 3, 2022',
#  'November 4, 2022',
#  'November 5, 2022',
#  'November 6, 2022',
#  'November 7, 2022',
#  'November 8, 2022',
#  'November 9, 2022',
#  'November 10, 2022',
#  'November 11, 2022',
#  'November 12, 2022',
#  'November 12, 2022',
#  'November 13, 2022',
#  'November 13, 2022',
#  'November 14, 2022',
#  'November 15, 2022',
#  'November 17, 2022',
#  'November 18, 2022',
#  'November 19, 2022',
#  'November 20, 2022',
#  'November 20, 2022',
#  'November 21, 2022',
#  'November 22, 2022',
#  'November 23, 2022',
#  'November 25, 2022',
#  'November 26, 2022',
#  'November 27, 2022',
#  'November 28, 2022',
#  'November 29, 2022',
#  'November 30, 2022',
#  'November 30, 2022',
#  'December 1, 2022',
#  'December 2, 2022',
#  'December 3, 2022',
#  'December 4, 2022',
#  'December 5, 2022',
#  'December 6, 2022',
#  'December 7, 2022',
#  'December 8, 2022',
#  'December 9, 2022',
#  'December 10, 2022',
#  'December 12, 2022',
#  'December 13, 2022',
#  'December 14, 2022',
#  'December 14, 2022',
#  'December 15, 2022',
#  'December 16, 2022',
#  'December 17, 2022',
#  'December 17, 2022',
#  'December 18, 2022',
#  'December 18, 2022',
#  'December 18, 2022',
#  'December 19, 2022',
#  'December 19, 2022',
#  'December 20, 2022',
#  'December 20, 2022',
#  'December 21, 2022',
#  'December 21, 2022',
#  'December 22, 2022',
#  'December 23, 2022',
#  'December 24, 2022',
#  'December 24, 2022',
#  'December 30, 2022',
#  'December 31, 2022',
#  'January 4, 2023',
#  'January 6, 2023',
#  'January 7, 2023',
#  'January 13, 2023',
#  'January 14, 2023',
#  'January 19, 2023',
#  'January 20, 2023',
#  'January 21, 2023',
#  'January 27, 2023',
#  'January 28, 2023',
#  'January 29, 2023',
#  'January 30, 2023',
#  'February 2, 2023',
#  'February 3, 2023',
#  'February 4, 2023',
#  'February 6, 2023',
#  'February 7, 2023',
#  'February 9, 2023',
#  'February 11, 2023',
#  'February 14, 2023',
#  'February 15, 2023',
#  'February 16, 2023',
#  'February 17, 2023',
#  'February 18, 2023',
#  'February 23, 2023',
#  'February 24, 2023',
#  'February 25, 2023',
#  'March 4, 2023']

# %%
# Cleaned up time
timemulti = [x.split(' at ',1)[-1] for x in tdmulti]
timemulti = [x.split('\n' ,1)[0] for x in timemulti]
timemulti
# Out:
# ['8:00 PM CDT',
#  '8:00 PM CDT',
#  '6:00 PM CDT',
#  '8:00 PM CDT',
#  '7:30 PM CDT',
#  '7:30 PM CDT',
#  '5:30 PM CDT',
#  '7:30 PM CDT',
#  '5:30 PM CDT',
#  '7:30 PM CDT',
#  '8:00 PM CDT',
#  '7:00 PM CDT',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '7:00 PM CST',
#  '9:30 PM CST',
#  '4:00 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:00 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '7:00 PM CST',
#  '7:00 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '3:00 PM CST',
#  '7:30 PM CST',
#  '3:00 PM CST',
#  '7:00 PM CST',
#  '7:30 PM CST',
#  '7:00 PM CST',
#  '7:30 PM CST',
#  '3:00 PM CST',
#  '7:30 PM CST',
#  '3:00 PM CST',
#  '7:30 PM CST',
#  '7:00 PM CST',
#  '8:00 PM CST',
#  '1:00 PM CST',
#  '5:00 PM CST',
#  '8:00 PM CST',
#  '9:00 PM CST',
#  '7:30 PM CST',
#  '7:00 PM CST',
#  '7:00 PM CST',
#  '7:00 PM CST',
#  '7:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '7:00 PM CST',
#  '8:00 PM CST',
#  '8:00 AM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '7:30 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST',
#  '8:00 PM CST']

# %% [markdown]
# Make tables DataFrames.

# %%
artistsmulti = pd.DataFrame(artistsmulti)
datemulti = pd.DataFrame(datemulti)
timemulti = pd.DataFrame(timemulti)

# %% [markdown]
# Combine three tables into one. Rename columns.

# %%
schedule_page_1_5 = pd.concat([artistsmulti,datemulti,timemulti], axis = 1)
schedule_page_1_5.columns = ['artist','date', 'time']
schedule_page_1_5
# Out:
#                      artist               date         time
# 0                   Mt. Joy   October 28, 2022  8:00 PM CDT
# 1                   Mt. Joy   October 29, 2022  8:00 PM CDT
# 2   Ryman Sidewalk Sessions   October 30, 2022  6:00 PM CDT
# 3            Marcus Mumford   October 30, 2022  8:00 PM CDT
# 4                  Puscifer   October 31, 2022  7:30 PM CDT
# ..                      ...                ...          ...
# 95         Kathleen Madigan  February 18, 2023  8:00 PM CST
# 96     Tedeschi Trucks Band  February 23, 2023  8:00 PM CST
# 97     Tedeschi Trucks Band  February 24, 2023  8:00 PM CST
# 98     Tedeschi Trucks Band  February 25, 2023  8:00 PM CST
# 99                    Dawes      March 4, 2023  8:00 PM CST
#
# [100 rows x 3 columns]

# %% [markdown]
# Add in opening acts.

# %%
page = 1
artistsmulti = []
while page != 6:
      url = f"https://ryman.com/events/list/?tribe_event_display=list&tribe_paged={page}"
      response = requests.get(url)
      html = response.content
      soup = bs(html, "lxml")
      for h3 in soup.find_all('span', attrs={'class': 'opener'}):
            artistsmulti.append(h3.get_text(strip=False))
      page = page + 1
artistsmulti
# Out:
# ['with The Brook & The Bluff',
#  'with The Brook & The Bluff',
#  'with Ben Patrick',
#  'with Night Club',
#  'with Shutterdog',
#  '2nd Show Added!',
#  'with Ashley Cooke and Dylan Marlowe',
#  'with Michael Leatherman',
#  'with Ashley Cooke and Dylan Marlowe',
#  'with BAILEN',
#  'with Cory Asbury plus special guests',
#  'with Paris Jackson',
#  '2nd Show Added!',
#  'with Paris Jackson',
#  'with special guest Ritt Momney',
#  'An evening of words, music and some mischief ...',
#  'with Jervis Campbell & special guests',
#  'with special guest Ray Fulcher',
#  'Dave Landau & Steven Crowder',
#  '2nd Show Added',
#  'Dave Landau & Steven Crowder',
#  ' ',
#  'Costume Palooza',
#  'Special PBS Television Taping',
#  'with Greyhounds',
#  'with special guests Aaron Cole and Lakewood Music',
#  'Yelawolf & Shooter Jennings introduce',
#  'with Bones Owens, Tony Martinez and Revelry',
#  'with Devon Gilfillian',
#  'This Machine ... Theater Tour',
#  'with special guests Jaime Wyatt and Jesse Ahern',
#  'Tokens Show presents',
#  'hosted by Lee C. Camp, featuring JOHNNYSWIM and more',
#  'Live at the Opry House',
#  'featuring BRELAND, Conner Smith, Elvie Shane, Nate Smith, Restless Road, Hailey Whitters & host Priscilla Block',
#  'with special guests Chris Young, Phil Vassar, Essex County and The Frontmen',
#  'The Prototype Tour',
#  'with Ravyn Lenae',
#  '40 Years Live World Tour',
#  'with special guest Armored Saint',
#  'Glow Live Tour',
#  'Glow Live Tour',
#  'Glow Live Tour',
#  'Celebrate Christmas Tour',
#  'with Wage War',
#  ' ',
#  'with special guest JD McPherson',
#  'with special guest JD McPherson',
#  'Thom Yorke, Jonny Greenwood, Tom Skinner',
#  'Behold the Lamb of God',
#  'Behold the Lamb of God',
#  'The Behold Christmas Tour',
#  'The Behold Christmas Tour',
#  'The Behold Christmas Tour',
#  'The 6th Annual',
#  'Joy: The Holiday Show',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  ' ',
#  'Christmas at the Ryman',
#  'Music & Memories',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  ' ',
#  'A Drummer Boy Christmas2nd Show Added On December 19! ',
#  'Christmas at the Ryman',
#  ' 2nd Show Added!',
#  'A Drummer Boy Christmas',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  'Christmas at the Ryman',
#  'with David Phelps',
#  'with Texas Hill, Abby Anderson, Brooke Eden, Caroline Jones and more',
#  'with Molly Tuttle & Golden Highway',
#  'with Molly Tuttle & Golden Highway',
#  'with Steve Earle & The Dukes and Friends',
#  '2nd Show Added!',
#  'with Monica Martin',
#  'with Monica Martin',
#  'with Samantha Fish',
#  'with Mammoth WVH and Red',
#  'with Tyler Braden',
#  'with Tyler Braden',
#  'with Slayyyter',
#  ' ',
#  'with Momma',
#  'featuring Aaron Raitiere, Benjy Davis, Brandy Clark, Caylee Hammack, Pillbox Patti, TJ Osborne and bandleader John Osborne',
#  'featuring Aaron Raitiere, Benjy Davis, Brandy Clark, Pillbox Patti, TJ Osborne and bandleader John Osborne',
#  'featuring Victor Wooten with support from Trousdale',
#  'with Amy Ray Band']
